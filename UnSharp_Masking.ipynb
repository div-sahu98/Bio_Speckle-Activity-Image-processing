# %%
from skimage import io, img_as_float
from skimage.filters import unsharp_mask,gaussian
from skimage import *
import numpy as np
import os
import random
import matplotlib.pyplot as plt
import cv2
from matplotlib import pyplot as plt

# %%
DIRECTORY=r'C:\Users\Divyansh\Desktop'
#DIRECTORY_2=r'C:\Users\Divyansh\Desktop\yest_img'
CATEGORIES=['DataCoffeeSeed']

# %%
count=1000
for category in CATEGORIES:
    folder=os.path.join(DIRECTORY,category)
    for img in os.listdir(folder):
            img_path =os.path.join(folder,img)
            img1 = img_as_float(io.imread(img_path, as_gray=True))
            gaussian_img = gaussian(img1, sigma=0.5, mode='constant', cval=0.0)
            img2 = (img1 - gaussian_img)*2.
            img3 = (img1 + img2)
            plt.imshow(img3)
            #plt.imshow(img1)
            break;
            #count=count+1
            #img_path_2 =os.path.join(folder,img)
            #io.imsave(r'C:\Users\Divyansh\Desktop\yest_img\\'+str(count)+".jpeg",img3)

print(count)
# Out:
# 1000
